# %%
# Question 1:

def Pairs(arr, sum):
    n=len(arr)
    count = 0
    for i in range(0, n):
        for j in range(i + 1, n):
            if arr[i] + arr[j] == sum:
                count += 1
 
    return count
 
print('Enter elements of array')
arr = list(map(int,input().split()))
sum = int(input("Enter sum "))
print("Count of pairs is",
      Pairs(arr, sum))
# Out:
# Enter elements of array
# 1 2 3 4
# Enter sum 10
# Count of pairs is 0

# %%
# Question 2
import array as arr1
a=arr1.array('i', [])
n=int(input("Enter the size of the array: "))
print("Enter element of the array, one at a time: ")
for i in range(n):
    ele=int(input())
    a.append(ele)
    
print("The original array is: ")
for i in range(n):
    print(a[i],end=" ")
    
print(' ')

for i in range(n//2):
    a[i],a[n-1-i]=a[n-1-i],a[i]
    
print("The reversed array is: ")
for i in range(n):
    print(a[i],end=" ")
# Out:
# Enter the size of the array: 5
# Enter element of the array, one at a time:
# 2
# 33
# 123
# 456
# 123
# The original array is:
# 2 33 123 456 123
# The reversed array is:
# 123 456 123 33 2

# %%
def check_rotation(a,b):
 
    if (len(a) != len(b)):
        return 0
 
# pushing string 1 in queue q1
    q1 = []
    for i in range(len(a)):
        q1.insert(0, a[i])
 
# pushing string 2 in queue 2
    q2 = []
    for i in range(len(b)):
        q2.insert(0, b[i])
 
    k = len(b)
    while (k > 0):
        ch = q2[0]
        q2.pop(0)
        q2.append(ch)
        if (q2 == q1):
            return True
 
        k -= 1
 
    return False

if __name__ == "__main__":
 
    s1 = "ABCD"   
    s2 = "CDAB"
    if (check_rotation(s1, s2)):
        print(s2, " is a rotated form of ", s1)
 
    else:
        print(s2, " is not a rotated form of ", s1)
 
    s3 = "ACBD"
    if (check_rotation(s1, s3)):
        print(s3, " is a rotated form of ", s1)
 
    else:
        print(s3, " is not a rotated form of ", s1)
        
    s4=input('Enter string 1: ')
    s5=input('Enter string 2: ')
    if (check_rotation(s4, s5)):
        print(s5, " is a rotated form of ", s4)
 
    else:
        print(s5, " is not a rotated form of ", s4)
# Out:
# CDAB  is a rotated form of  ABCD
# ACBD  is not a rotated form of  ABCD

# %%
# Question 4:

c = 256
def CharCount(string):
    count = [0] * c
    for i in string:
        count[ord(i)]+= 1
    return count
 
def firstNonRepeating(string):
    count = CharCount(string)
    index = -1
    k = 0
 
    for i in string:
        if count[ord(i)] == 1:
            index = k
            break
        k += 1
 
    return index
 
string = input("Enter String: ")
index = firstNonRepeating(string)
if index == 1:
    print ("Either all characters are repeating or string is empty")
else:
    print ("First non-repeating character is" , string[index])

# %%
 Question 5

def TowerOfHanoi(n , source, destination, path):
    if n==1:
        print ("Move disk 1 from source",source,"to destination",destination)
        return
    TowerOfHanoi(n-1, source, path, destination)
    print ("Move disk",n,"from source",source,"to destination",destination)
    TowerOfHanoi(n-1, path, destination, source)
         

n = 4
TowerOfHanoi(n,'A','B','C',)

# %%
# Question 6

def isOperator(x):
 
    if x == "+":
        return True
 
    elif x == "-":
        return True
 
    elif x == "/":
        return True
 
    elif x == "*":
        return True
 
    else:
        return False
 
 
def postToPre(post_exp):
 
    s = []
 
    
    l = len(post_exp)
 
    for i in range(l):
        
        if (isOperator(post_exp[i])):
            op1 = s[-1]
            s.pop()
            op2 = s[-1]
            s.pop()
            temp = post_exp[i] + op2 + op1
            s.append(temp)
 
        else:
            s.append(post_exp[i])
 
    exp = ""
    for i in s:
        exp += i
    return exp
 
 
if __name__ == "__main__":
 
    post_exp = "AB+CD-"
    print("Prefix : ", postToPre(post_exp))
    
    post_exp = input("Enter postfix expression: ")
    print("Prefix : ", postToPre(post_exp))

# %%
def preToIn(pre):
    s = []
     
    i = len(pre) - 1
    while i >= 0:
        
        if not isOperator(pre[i]):
            s.append(pre[i])
            i -= 1
        
        else:
            exp = "(" + s.pop() + pre[i] + s.pop() + ")"
            s.append(exp)
            i -= 1
     
    return s.pop()
 
def isOperator(c):
    if c == "*" or c == "+" or c == "-" or c == "/" or c == "^" or c == "(" or c == ")":
        return True
    else:
        return False
 
if __name__=="__main__":
    str = "*-A/BC-/AKL"
    print(preToIn(str))
    
    str = input("Enter prefix expression")
    print(preToIn(str))

# %%
def isBalanced(expr):
    s = []
 
    
    for char in expr:
        
        if char in ["(", "{", "["]:
            s.append(char)
        
        else:
            if not s:
                return False
            current_char = s.pop()
            if current_char == '(':
                if char != ")":
                    return False
            if current_char == '{':
                if char != "}":
                    return False
            if current_char == '[':
                if char != "]":
                    return False
 
    
    if s:
        return False
    return True

if __name__ == "__main__":
    exp = "{()}[]"
    if isBalanced(exp):
        print("Balanced")
    else:
        print("Not Balanced")
        
    
    exp = input("Enter expression: ")
    if isBalanced(exp):
        print("Balanced")
    else:
        print("Not Balanced")

# %%
class Stack:

    def __init__(self):
        self.Elements = []
         
    def push(self, value):
        self.Elements.append(value)
       
    def pop(self):
        return self.Elements.pop()
     
    def empty(self):
        return self.Elements == []
     
    def show(self):
        for value in reversed(self.Elements):
            print(value)
 

def BottomInsert(s, value):
    
    if s.empty():
        s.push(value)
         
    else:
        popped = s.pop()
        BottomInsert(s, value)
        s.push(popped)
 

def Reverse(s):
    if s.empty():
        pass
    else:
        popped = s.pop()
        Reverse(s)
        BottomInsert(s, popped)
        
 # create object of stack class
stk = Stack()
 
stk.push(1)
stk.push(2)
stk.push(3)
stk.push(4)
stk.push(5)
 
print("Original Stack")
stk.show()
 
print("\nStack after Reversing")
Reverse(stk)
stk.show()

# %%
class Node:
    
    def __init__(self, value):
        self.value = value
        self.next = None
 
    def __str__(self):
        return "Node({})".format(self.value)
     

    __repr__ = __str__
 
 
class Stack:
    
    def __init__(self):
        self.top = None
        self.count = 0
        self.minimum = None
         
    
    def __str__(self):
        temp = self.top
        out = []
        while temp:
            out.append(str(temp.value))
            temp = temp.next
        out = '\n'.join(out)
        return ('Top {} \n\nStack :\n{}'.format(self.top,out))
         
    
    __repr__=__str__
     

    def getMin(self):
        if self.top is None:
            return "Stack is empty"
        else:
            print("Minimum Element in the stack is: {}" .format(self.minimum))
        
    def isEmpty(self):
        if self.top == None:
            return True
        else:
            return False
 
        
    def __len__(self):
        self.count = 0
        tempNode = self.top
        while tempNode:
            tempNode = tempNode.next
            self.count+=1
        return self.count
 
    
    def peek(self):
        if self.top is None:
            print ("Stack is empty")
        else:
            if self.top.value < self.minimum:
                print("Top Most Element is: {}" .format(self.minimum))
            else:
                print("Top Most Element is: {}" .format(self.top.value))
 
    def push(self,value):
        if self.top is None:
            self.top = Node(value)
            self.minimum = value
         
        elif value < self.minimum:
            temp = (2 * value) - self.minimum
            new_node = Node(temp)
            new_node.next = self.top
            self.top = new_node
            self.minimum = value
        else:
            new_node = Node(value)
            new_node.next = self.top
            self.top = new_node
        print("Number Inserted: {}" .format(value))
        
    def pop(self):
        if self.top is None:
            print( "Stack is empty")
        else:
            removedNode = self.top.value
            self.top = self.top.next
            if removedNode < self.minimum:
                print ("Top Most Element Removed :{} " .format(self.minimum))
                self.minimum = ( ( 2 * self.minimum ) - removedNode )
            else:
                print ("Top Most Element Removed : {}" .format(removedNode))
 
                 
             
     
# Test Run
stack = Stack()
 
stack.push(3)
stack.push(5)
stack.getMin()
stack.push(2)
stack.push(1)
stack.getMin()    
stack.pop()
stack.getMin()
stack.pop()
stack.peek()
